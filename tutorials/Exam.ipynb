# %% [markdown]
# # Computational Economics: Final Exam.
#
# __Name__:
#
# __Surname__:
#
# Duration: 2h

# %% [markdown]
# ## Part 1 : Programming bits

# %% [markdown]
# ## Linear Regression
#
# 1. __For $N=100$, compute a sample $(x_i, y_i)_{i=[1:N]}$ satisfying $$y_i=0.2+3.5 x_i + \epsilon_i$$ where $x_i$ is *uniformly* distributed between 0 and 1 and $\epsilon_i$ is drawn from a normal distribution with standard deviation 0.5.__

# %% [markdown]
# 2. __Define the model $f(x;a,b)=a+b x$. Find the parameters $a$ and $b$ which minimize the objective $\xi(a,b)=\sum_i (f(x_i;a,b)-y_i)^2$ by using a numerical optimization algorithm (not the formula for the regression). Plot.__
#
# <mark>Hint</mark>: you can write your own gradient descent algorithm or use an optimization library).

# %% [markdown]
# 3. __Compare the result against the exact solution (for the given sample $(x_i, y_i)$__

# %% [markdown]
# ### Power iteration method
#
# In this exercise, we implement a power iteration method `power_iteration(M::Matrix)` to compute the biggest eigenvalue of a given matrix `M`.

# %% [markdown]
# __Define a random 3 times 3 matrix `M`. Compute its biggest eigenvalue using `LinearAlgebra: eigvals`.__

# %% [markdown]
# __Define a `norm2` function, which computes the euclidean norm of any vector. Test it on some simple cases.__

# %% [markdown]
# __Write a function `iteration_step(M::Matrix, u::Vector)::Tuple{Float64, Vector}` which takes a random vector $u$ with norm 1 and returns $M u$ and $\frac{M u}{|M u|}$__

# %% [markdown]
# __Write a function `power_iteration(M::Matrix)::Float64`, which computes the spectral radius of `M` using the power iteration method (link from the [course](http://www.mosphere.fr/eco309/slides/perturbation.html#/4/7)). (spectral radius: absolute value of biggest eigenvalue)__

# %% [markdown]
# __Check the result is correct on matrix $M$.__

# %% [markdown]
# ### Doubling algorithm
#
# Let $M$ be a square matrix with spectral radius smaller than 1. Our goal here to approximate the infinite sum $\sum_{t\geq 0} M^t$ (whose result is a matrix).

# %% [markdown]
# __Define a 3x3 matrix M with spectral radius smaller than 1.__

# %% [markdown]
# __Propose an algorithm and a function `infinite_sum(M::Matrix)` to approximate this sum by computing the limit of $S_T = \sum_{t=0}^{T} M^t$ when $T$ goes to $\infty$.__

# %% [markdown]
# __We now consider the doubling algorithm. Consider the sum $D_N = \sum_{t\geq 0}^{2^N} M^t$. Find a recursive relation between $D_N$ and $D_{N+1}$. Why is $D_N$ less expansive to compute than $S^{2 N}$ ?__

# %% [markdown]
# __Implement a function `infinite_sum_doubling(M::Matrix)` which computes the infinite sum using the doubling algorithm. Check the result and time it against the other implementation.__

# %% [markdown]
# ## Part 2: reduced New Keyesian model

# %% [markdown]
# We consider the reduced-form New Keynesian Model
#
# $$\pi_t = \alpha E_t \pi_{t+1} + y_t$$
#
# $$y_t = \beta E_t y_{t+1} + \gamma (i_t-\pi_t) + \delta z_t$$
#
# $$i_t = \alpha_{y} y_t + \alpha_{\pi} \pi_t$$
#
# where $\pi_t$ is inflation, $y_t$ the output gap (i.e, the gap to full employment), and $z_t$ an AR1 process given by:
#
# $$z_t = \rho z_{t-1} + \epsilon_t$$
#
# wher $\epsilon_t$ is a random gaussian process with standard deviation $\sigma_{\epsilon}$.
#
# We'll take $\alpha=0.9$, $\beta=0.9$, $\gamma=0.1$, $\alpha_{\pi}=0.5$, $\alpha_y=0.5$, $\rho=0.9$ and $\sigma=0.01$.

# %% [markdown]
# ### Model Solution

# %% [markdown]
# __Define matrices $A$ (2x2) and $B$ (2x1) such that:__
#
# $$\begin{bmatrix}\pi_t\\y_t\end{bmatrix} = A E_t \begin{bmatrix}\pi_{t+1}\\y_{t+1}\end{bmatrix} + B z_t$$

# %%
# text

# %%
# code
function create_matrices(parameters)
#     A = ...
#     B = ...
    return A, B
end

# %% [markdown]
# __Express $\begin{bmatrix}\pi_t\\y_t\end{bmatrix}$ as a function of $z_t, z_{t+1}, ...$, using an infinite sum.__

# %%
# text

# %%
# code

# %% [markdown]
# __Show that we can write $\begin{bmatrix}\pi_t\\y_t\end{bmatrix}=\sum_{s\geq0} \rho^s M^s B z_t$. At which condition on $A$ is this sum absolutely converging?__

# %% [markdown]
# __Check that this condition is met for the baseline calibration.__

# %% [markdown]
# __Bonus: find conditions on $\alpha_y$ and $\alpha_{\pi}$ for the sum to be convergent. When it is, in this context, we say that inflation is *anchored*.__

# %% [markdown]
# __Compute the solution  to the system, that is find to sacalars $x_y$ and $x_{\pi}$  such that $y_t(z) = x_{y} z_t$ and $\pi_t(z)= x_{\pi} z_t$ solve the system.__

# %% [markdown]
# __Compute matrices $P$ and $Q$ such that $\begin{bmatrix}\pi_t\\y_t\\z_t\end{bmatrix} =  P \begin{bmatrix}\pi_{t-1}\\y_{t-1}\\z_{t-1}\end{bmatrix} + Q \epsilon_t$__

# %% [markdown]
# __Simulate variables $\pi_t, y_t, z_t$ when $\pi_0 =  y_0 = 0, z_0=0.1$  and $\forall t, \epsilon_t = 0$__

# %% [markdown]
# __Make $N=1000$ stochastic simulations for $T=200$ periods. Compute ergodic standard deviations, that is the std taken in period 200 over all simulations.__
