# %%
from interpolation.splines.basis_splines import B

# %%
from matplotlib import pyplot as plt

# %%
B?
# Out:
# Signature: B(p, u, i, x)
# Docstring: <no docstring>
# File:      ~/.local/opt/anaconda3/lib/python3.7/site-packages/interpolation/splines/basis_splines.py
# Type:      function

# %%
import numpy as np

# %%
N = 100
u = np.linspace( 0,1, N)

# %%
x = np.linspace(-0.2, 1.2, 1000)

# %%
for i in range(9):
    plt.plot(x, np.array([B(2, u, i, xx) for xx in x]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-6fe0e75caab1> in <module>
#       1 for i in range(9):
# ----> 2     plt.plot(x, np.array([B(2, u, i, xx) for xx in x]))
#
# <ipython-input-21-6fe0e75caab1> in <listcomp>(.0)
#       1 for i in range(9):
# ----> 2     plt.plot(x, np.array([B(2, u, i, xx) for xx in x]))
#
# ~/.local/opt/anaconda3/lib/python3.7/site-packages/interpolation/splines/basis_splines.py in B(p, u, i, x)
#      13         return B0(u, i, x)
#      14     else:
# ---> 15         return (((x - u[i]) / (u[i + p] - u[i])) * B(p - 1, u, i, x) + ((u[i + p + 1] - x) / (u[i + p + 1] - u[i + 1])) * B(p - 1, u, i + 1, x))
#      16
#      17 #
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
bases = [np.array([B(2, u, i, xx) for xx in x]) for i in range(-1, N-3)]

# plt.plot(x, np.array([B(2, u, 7, xx) for xx in x]))
# plt.plot(x, np.array([B(2, u, 8, xx) for xx in x]))
# plt.plot(x, np.array([B(2, u, 9, xx) for xx in x]))

# %%
plt.plot(x, sum(bases))

# %%
f = lambda x: np.sin(x)

# %%
uf = f(u)

# %%
approx = sum( f(u[i])*b for (i,b) in enumerate(bases))

# %%
plt.plot(x, f(x))
plt.plot(x, approx)
