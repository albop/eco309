# %% [markdown]
# # Julia concepts

# %% [markdown]
# ## Julia setup

# %% [markdown]
# ### Console
#
# Diffrent modes:
# >
# ;
# ?
# ]

# %% [markdown]
# ### Kernel, Jupyter notebook and JupyterLab

# %% [markdown]
# ## Modules

# %% [markdown]
# ## Package installation

# %% [markdown]
# ## Types

# %% [markdown]
# ### Inhéritance and abstract types

# %% [markdown]
# ### Multiple Dispatch

# %% [markdown]
# ### Generic types

# %% [markdown]
# ## Generators

# %% [markdown]
# ## Metaprogramming
